# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def return_dataframe(filename):
    return pd.read_csv(filename).set_index("id")

# %%
df = return_dataframe("nvc_WT_normal_noise_df.csv")
df_melted = pd.melt(df, id_vars=["number"], value_vars=['nvc_segment_0/2', 'nvc_segment_1/2'])

# print(df_melted)

ax = sns.barplot(x="number", y="value", hue="variable", data=df_melted)
plt.title("Neurovascular coupling (gaussian noise)")
plt.show()

ax = sns.barplot(x="variable", y="value", data=df_melted)
plt.title("Neurovascular coupling (gaussian noise, all mice)")
plt.show()

# %%
df = return_dataframe("nvc_WT_shuffled_noise_df.csv")
df_melted = pd.melt(df, id_vars=["number"], value_vars=['nvc_segment_0/2', 'nvc_segment_1/2'])

# print(df_melted)

ax = sns.barplot(x="number", y="value", hue="variable", data=df_melted)
plt.title("Neurovascular coupling (shuffled values)")
plt.show()

ax = sns.barplot(x="variable", y="value", data=df_melted)
plt.title("Neurovascular coupling (shuffled values, all mice)")
plt.show()

# %%
df = return_dataframe("funcsim_WT_normal_noise_df.csv")
df_melted = pd.melt(df, id_vars=["number"], value_vars=['funcsim_segment_0/2', 'funcsim_segment_1/2'])

# print(df_melted)

ax = sns.barplot(x="number", y="value", hue="variable", data=df_melted)
plt.title("Functional similarity (gaussian noise)")
plt.show()

ax = sns.barplot(x="variable", y="value", data=df_melted)
plt.title("Functional similarity (gaussian noise, all mice)")
plt.show()

df = return_dataframe("funcsim_WT_shuffled_noise_df.csv")
df_melted = pd.melt(df, id_vars=["number"], value_vars=['funcsim_segment_0/2', 'funcsim_segment_1/2'])

# print(df_melted)

ax = sns.barplot(x="number", y="value", hue="variable", data=df_melted)
plt.title("Functional similarity (shuffled values)")
plt.show()

ax = sns.barplot(x="variable", y="value", data=df_melted)
plt.title("Functional similarity (shuffled values, all mice)")
plt.show()

# %%
df = return_dataframe("funcrep_WT_normal_noise_df.csv")
df_melted = pd.melt(df, id_vars=["number"], value_vars=['GCaMP_funcrep_segment_0/2', 'GCaMP_funcrep_segment_1/2'])

# print(df_melted)

ax = sns.barplot(x="number", y="value", hue="variable", data=df_melted)
plt.title("Functional representativity (gaussian noise)")
plt.show()

ax = sns.barplot(x="variable", y="value", data=df_melted)
plt.title("Functional representativity (gaussian noise, all mice)")
plt.show()

df = return_dataframe("funcrep_WT_shuffled_noise_df.csv")
df_melted = pd.melt(df, id_vars=["number"], value_vars=['GCaMP_funcrep_segment_0/2', 'GCaMP_funcrep_segment_1/2'])

# print(df_melted)

ax = sns.barplot(x="number", y="value", hue="variable", data=df_melted)
plt.title("Functional representativity (shuffled values)")
plt.show()

ax = sns.barplot(x="variable", y="value", data=df_melted)
plt.title("Functional representativity (shuffled values, all mice)")
plt.show()

# %%
df = return_dataframe("modularity_WT_normal_noise_df.csv")
df_melted = pd.melt(df, id_vars=["number"], value_vars=['GCaMP_modularity_segment_0/2', 'GCaMP_modularity_segment_1/2'])

# print(df_melted)

ax = sns.barplot(x="number", y="value", hue="variable", data=df_melted)
plt.title("Modularity (gaussian noise)")
plt.show()

ax = sns.barplot(x="variable", y="value", data=df_melted)
plt.title("Modularity (gaussian noise, all mice)")
plt.show()

df = return_dataframe("modularity_WT_shuffled_noise_df.csv")
df_melted = pd.melt(df, id_vars=["number"], value_vars=['GCaMP_modularity_segment_0/2', 'GCaMP_modularity_segment_1/2'])

# print(df_melted)

ax = sns.barplot(x="number", y="value", hue="variable", data=df_melted)
plt.title("Modularity (shuffled values)")
plt.show()

ax = sns.barplot(x="variable", y="value", data=df_melted)
plt.title("Modularity (shuffled values, all mice)")
plt.show()
