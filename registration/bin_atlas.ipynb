# %%
import numpy as np
import matplotlib.pyplot as plt

atlas_input = f"D:/mouse_data/new_data/atlas/outline_mask_coarse.npy"
atlas_output = f"D:/mouse_data/new_data/atlas/outline_mask_coarse_binned.npy"

atlas = np.load(atlas_input)
print(atlas.shape)

binned_atlas = atlas[::2, ::2]

np.save(atlas_output, binned_atlas)

plt.imshow(atlas)
plt.show()

plt.imshow(binned_atlas)
plt.show()
# Out:
# (1265, 1092)
